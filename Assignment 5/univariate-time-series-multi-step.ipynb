# %%
import sys
import sklearn
import tensorflow as tf
from tensorflow import keras

import numpy as np
from numpy import load
import os

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ### Load Dataset

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$"):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bx", markersize=10)
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "ro")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "ro-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "bx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

# %% [markdown]
# ## Forecasting Several Steps Ahead
#
# If we want to predict the next 10 values, instead of just 1, we can modify our previous model to predict the next 10 values. We first need to load the dataset that has sequences with 9 more time steps.

# %%
n_steps = 60
series = load('univariate-time-series-multi-step.npy')

X_train, y_train = series[:9000, :n_steps], series[:9000, -1] # -1 references the last column
X_valid, y_valid = series[9000:11000, :n_steps], series[9000:11000, -1]
X_test, y_test = series[11000:, :n_steps], series[11000:, -1]

# %%
#Improve upon this model with your own model

model = keras.models.Sequential([                           
    keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
    keras.layers.Bidirectional(keras.layers.LSTM(60)),
    keras.layers.Dense(60, activation = 'relu'),
    keras.layers.Dropout(.15),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 282/282 [==============================] - 47s 135ms/step - loss: 0.0735 - val_loss: 0.0482
# Epoch 2/20
# 282/282 [==============================] - 37s 131ms/step - loss: 0.0429 - val_loss: 0.0385
# Epoch 3/20
# 282/282 [==============================] - 38s 135ms/step - loss: 0.0358 - val_loss: 0.0367
# Epoch 4/20
# 282/282 [==============================] - 37s 130ms/step - loss: 0.0333 - val_loss: 0.0301
# Epoch 5/20
# 282/282 [==============================] - 38s 133ms/step - loss: 0.0313 - val_loss: 0.0318
# Epoch 6/20
# 282/282 [==============================] - 38s 135ms/step - loss: 0.0297 - val_loss: 0.0282
# Epoch 7/20
# 282/282 [==============================] - 38s 135ms/step - loss: 0.0286 - val_loss: 0.0265
# Epoch 8/20
# 282/282 [==============================] - 38s 136ms/step - loss: 0.0271 - val_loss: 0.0254
# Epoch 9/20
# 282/282 [==============================] - 39s 138ms/step - loss: 0.0258 - val_loss: 0.0262
# Epoch 10/20
# 282/282 [==============================] - 39s 138ms/step - loss: 0.0241 - val_loss: 0.0227
# Epoch 11/20
# 282/282 [==============================] - 39s 138ms/step - loss: 0.0225 - val_loss: 0.0245
# Epoch 12/20
# 282/282 [==============================] - 39s 137ms/step - loss: 0.0209 - val_loss: 0.0205
# Epoch 13/20
# 282/282 [==============================] - 38s 136ms/step - loss: 0.0200 - val_loss: 0.0223
# Epoch 14/20
# 282/282 [==============================] - 38s 136ms/step - loss: 0.0192 - val_loss: 0.0185
# Epoch 15/20
# 282/282 [==============================] - 39s 137ms/step - loss: 0.0187 - val_loss: 0.0176
# Epoch 16/20
# 282/282 [==============================] - 39s 137ms/step - loss: 0.0174 - val_loss: 0.0164
# Epoch 17/20
# 282/282 [==============================] - 39s 138ms/step - loss: 0.0166 - val_loss: 0.0180
# Epoch 18/20
# 282/282 [==============================] - 39s 137ms/step - loss: 0.0160 - val_loss: 0.0167
# Epoch 19/20
# 282/282 [==============================] - 39s 138ms/step - loss: 0.0162 - val_loss: 0.0153
# Epoch 20/20
# 282/282 [==============================] - 38s 136ms/step - loss: 0.0157 - val_loss: 0.0151

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# Now let's predict the next 10 values:

# %%
series = load('univariate-time-series-multi-step-test.npy')
X_new, Y_new = series[:, :60, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %%
model.evaluate(X_test, y_test)

    # keras.layers.LSTM(60),
    # keras.layers.Flatten(input_shape=[60, 1]),
    # keras.layers.Dense(100),
    # keras.layers.Dense(10)
#     32/32 [==============================] - 0s 8ms/step - loss: 0.0275
# 0.027470536530017853

#     keras.layers.LSTM(60),
#     keras.layers.Flatten(input_shape=[60, 1]),\
#     keras.layers.Dense(100),\
#     keras.layers.Dense(10)
# ])
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0284
# 0.028448767960071564

#     keras.layers.LSTM(60),
#     keras.layers.Flatten(input_shape=[60, 1])
#     keras.layers.Dense(100),
#     keras.layers.Dropout(.15),
#     keras.layers.Dense(10)
# ])
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0281
# 0.028066053986549377

# keras.layers.LSTM(60, return_sequences=True),
#     keras.layers.LSTM(60),
#     keras.layers.Flatten(input_shape=[60, 1]),
#     keras.layers.Dense(100),
#     keras.layers.Dropout(.15),
#     keras.layers.Dense(10)
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0178
# 0.017804954200983047

# keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
#     keras.layers.Bidirectional(keras.layers.LSTM(60)),
#     keras.layers.Dense(100),
#     keras.layers.Dropout(.15),
#     keras.layers.Dense(10)
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0161
# 0.01605716347694397


#  keras.layers.Embedding(60,10) ,                             
#     keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
#     keras.layers.Bidirectional(keras.layers.LSTM(60)),
#     keras.layers.Dense(100),
#     keras.layers.Dropout(.15),
#     keras.layers.Dense(10)
# 32/32 [==============================] - 1s 27ms/step - loss: 0.1515
# 0.15153397619724274


    # keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
    # keras.layers.Bidirectional(keras.layers.LSTM(60)),
    # keras.layers.Dense(200),
    # keras.layers.Dropout(.15),
    # keras.layers.Dense(100),
    # keras.layers.Dropout(.15),
    # keras.layers.Dense(10)
# 32/32 [==============================] - 1s 29ms/step - loss: 0.0181
# 0.018115509301424026


    # keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
    # keras.layers.Bidirectional(keras.layers.LSTM(60)),
    # keras.layers.Dense(60),
    # keras.layers.Dropout(.15),
    # keras.layers.Dense(10)
#     32/32 [==============================] - 1s 26ms/step - loss: 0.0160
# 0.01604968123137951


    # keras.layers.LSTM(60, return_sequences=True),
    # keras.layers.LSTM(60),
    # keras.layers.Dense(60, activation = 'sigmoid'),
    # keras.layers.Dropout(.10),
    # keras.layers.Dense(10)
#     32/32 [==============================] - 1s 17ms/step - loss: 0.0177
# 0.01767544634640217

    # keras.layers.Bidirectional(keras.layers.LSTM(60, return_sequences=True)),
    # keras.layers.Bidirectional(keras.layers.LSTM(60)),
    # keras.layers.Dense(60, activation = 'relu'),
    # keras.layers.Dropout(.15),
    # keras.layers.Dense(10)
#     32/32 [==============================] - 1s 30ms/step - loss: 0.0140
# 0.01395788136869669
# Out:
# 32/32 [==============================] - 1s 34ms/step - loss: 0.0140
# 0.01395788136869669
